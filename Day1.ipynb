# %%
print(1+6)
print("Hello, World!")
print("This is a sample Python script.")
print("Let's perform some basic arithmetic:")
print("5 * 3 =", 5 * 3)
print("10 / 2 =", 10 / 2)
print("Goodbye!")
print("\"test\"")
# Out:
# 7
# Hello, World!
# This is a sample Python script.
# Let's perform some basic arithmetic:
# 5 * 3 = 15
# 10 / 2 = 5.0
# Goodbye!
# "test"
